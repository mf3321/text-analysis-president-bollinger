# %%
# Importing libraries

import pandas as pd
import numpy as np
from textblob import TextBlob

# %%
# Opening each text file; reading all text for that file as a single line and
# naming it as a variable; passing each of these as agrument into the TextBlob 
# function, assigning the result to a new variable

a = open("2003_Bollinger.txt","r")
b2003 = a.readline()
a1 = TextBlob(b2003)

b = open("2004_Bollinger.txt","r")
b2004 = b.readline()
b1 = TextBlob(b2004)

c = open("2005_Bollinger.txt","r")
b2005 = c.readline()
c1 = TextBlob(b2005)

d = open("2006_Bollinger.txt","r")
b2006 = d.readline()
d1 = TextBlob(b2006)

e = open("2007_Bollinger.txt","r")
b2007 = e.readline()
e1 = TextBlob(b2007)

f = open("2008_Bollinger.txt","r")
b2008 = f.readline()
f1 = TextBlob(b2008)

g = open("2009_Bollinger.txt","r")
b2009 = g.readline()
g1 = TextBlob(b2009)

h = open("2010_Bollinger.txt","r")
b2010 = h.readline()
h1 = TextBlob(b2010)

i = open("2011_Bollinger.txt","r")
b2011 = i.readline()
i1 = TextBlob(b2011)

j = open("2012_Bollinger.txt","r")
b2012 = j.readline()
j1 = TextBlob(b2012)

k = open("2013_Bollinger.txt","r")
b2013 = k.readline()
k1 = TextBlob(b2013)

l = open("2014_Bollinger.txt","r")
b2014 = l.readline()
l1 = TextBlob(b2014)

m = open("2015_Bollinger.txt","r")
b2015 = m.readline()
m1 = TextBlob(b2015)

n = open("2016_Bollinger.txt","r")
b2016 = n.readline()
n1 = TextBlob(b2016)

o = open("2017_Bollinger.txt","r")
b2017 = o.readline()
o1 = TextBlob(b2017)

p = open("2018_Bollinger.txt","r")
b2018 = p.readline()
p1 = TextBlob(b2018)

q = open("2019_Bollinger.txt","r")
b2019 = q.readline()
q1 = TextBlob(b2019)

r = open("2020_Bollinger.txt","r")
b2020 = r.readline()
r1 = TextBlob(b2020)

s = open("2021_Bollinger.txt","r")
b2021 = s.readline()
s1 = TextBlob(b2021)

t = open("2022_Bollinger.txt","r")
b2022 = s.readline()
t1 = TextBlob(b2022)

u = open("2023_Bollinger.txt","r")
b2023 = s.readline()
u1 = TextBlob(b2023)

# %%
print("2003 address sentiment analysis:", a1.sentiment)
print("2004 address sentiment analysis:", b1.sentiment)
print("2005 address sentiment analysis:", c1.sentiment)
print("2006 address sentiment analysis:", d1.sentiment)
print("2007 address sentiment analysis:", e1.sentiment)
print("2008 address sentiment analysis:", f1.sentiment)
print("2009 address sentiment analysis:", g1.sentiment)
print("2010 address sentiment analysis:", h1.sentiment)
print("2011 address sentiment analysis:", i1.sentiment)
print("2012 address sentiment analysis:", j1.sentiment)
print("2013 address sentiment analysis:", k1.sentiment)
print("2014 address sentiment analysis:", l1.sentiment)
print("2015 address sentiment analysis:", m1.sentiment)
print("2016 address sentiment analysis:", n1.sentiment)
print("2017 address sentiment analysis:", o1.sentiment)
print("2018 address sentiment analysis:", p1.sentiment)
print("2019 address sentiment analysis:", q1.sentiment)
print("2020 address sentiment analysis:", r1.sentiment)
print("2021 address sentiment analysis:", s1.sentiment)
print("2022 address sentiment analysis:", t1.sentiment)
print("2023 address sentiment analysis:", u1.sentiment)
# Out:
# 2003 address sentiment analysis: Sentiment(polarity=0.062037037037037036, subjectivity=0.30833333333333335)
# 2004 address sentiment analysis: Sentiment(polarity=0.48888888888888893, subjectivity=0.6717592592592593)
# 2005 address sentiment analysis: Sentiment(polarity=0.15238095238095237, subjectivity=0.42023809523809524)
# 2006 address sentiment analysis: Sentiment(polarity=0.3, subjectivity=0.3787414965986394)
# 2007 address sentiment analysis: Sentiment(polarity=1.0, subjectivity=0.9750000000000001)
# 2008 address sentiment analysis: Sentiment(polarity=0.8, subjectivity=0.75)
# 2009 address sentiment analysis: Sentiment(polarity=1.0, subjectivity=0.9750000000000001)
# 2010 address sentiment analysis: Sentiment(polarity=0.19166666666666668, subjectivity=0.545)
# 2011 address sentiment analysis: Sentiment(polarity=0.35757575757575755, subjectivity=0.5787878787878789)
# 2012 address sentiment analysis: Sentiment(polarity=0.5131944444444444, subjectivity=0.7604166666666666)
# ...
